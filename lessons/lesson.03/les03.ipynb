# %%
x = 10

# %% [markdown]
# int
# float
# str
# bool
# None

# %%
x = 1
print(type(x))
# Out:
# <class 'int'>

# %%
x = -778898723
print(type(x))
# Out:
# <class 'int'>

# %%
x = 0
print(type(x))
# Out:
# <class 'int'>

# %%
age = 27
year = 2027
temp = -7

# %%
res = year + age
print(res)
# Out:
# 2054

# %%
res = year - age
print(res)
# Out:
# 2000

# %%
res = year * age
print(res)
# Out:
# 54729

# %%
res = year / age
print(res)
# Out:
# 75.07407407407408

# %%
x = 20
y = 5
res = x / y
print(res)
print(type(res))
# Out:
# 4.0
# <class 'float'>

# %%
x = 17
y = 5
res = x / y
print(res)
# Out:
# 3.4

# %%
x = 17
y = 5
res = x // y
print(res)
# Out:
# 3

# %%
x = 17
y = 5
res = x % y
print(res)
# Out:
# 2

# %%
x = 17
y = 5
res = x ** y
print(res)
# Out:
# 1419857

# %%
res = year / age
print(res)
# Out:
# 75.07407407407408

# %%
res = year / age
print(res)
print(type(res))
new_res = int(res)
print(new_res)
print(type(new_res))
# Out:
# 75.07407407407408
# <class 'float'>
# 75
# <class 'int'>

# %%
res = int(1.97)
print(res)
# Out:
# 1

# %%
res = int("1.97")
print(res)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 res = int("1.97")
#       2 print(res)
#
# ValueError: invalid literal for int() with base 10: '1.97'

# %%
res = int("1")
print(res)
# Out:
# 1

# %%
res = 12345.6789
print(res)
print(type(res))
new_res = round(res)
print(new_res)
print(type(new_res))
# Out:
# 12345.6789
# <class 'float'>
# 12346
# <class 'int'>

# %%
res = 12345.6789
print(res)
print(type(res))
new_res = round(res, 0)
print(new_res)
print(type(new_res))
# Out:
# 12345.6789
# <class 'float'>
# 12346.0
# <class 'float'>

# %%
res = 12345.6789
print(res)
print(type(res))
new_res = round(res, 2)
print(new_res)
print(type(new_res))
# Out:
# 12345.6789
# <class 'float'>
# 12345.68
# <class 'float'>

# %%
res = 12345.6789
print(res)
print(type(res))
new_res = round(res, -2)
print(new_res)
print(type(new_res))
# Out:
# 12345.6789
# <class 'float'>
# 12300.0
# <class 'float'>

# %%
x: int = 1
y: float = 1
# так можно предварительно объявлять тип данных?
print(type(x))
print(type(y))
# Out:
# <class 'int'>
# <class 'int'>

# %%
x: int = 1
y: float = 1.0
# так можно предварительно объявлять тип данных?
print(type(x))
print(type(y))
# Out:
# <class 'int'>
# <class 'float'>

# %%
x: int = "1qaz"
y: float = 1.0
# так можно предварительно объявлять тип данных?
print(type(x))
print(type(y))
# Out:
# <class 'str'>
# <class 'float'>

# %%
x = 1
x = 'qaz'

# %%
age = input("Please input your age: ")
print(type(age))
print(age)

res = age + 1
print(res)
# Out:
# <class 'str'>
# 12
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[35], line 5
#       1 age = input("Please input your age: ")
#       2 print(type(age))
#       3 print(age)
#       4
# ----> 5 res = age + 1
#       6 print(res)
#       7
#
# TypeError: can only concatenate str (not "int") to str

# %%
age = input("Please input your age: ")
print(type(age))
print(age)

res = int(age) + 1
print(res)
# Out:
# <class 'str'>
# 12
# 13

# %%
age = int(input("Please input your age: "))
print(type(age))
print(age)

res = age + 1
print(res)
# Out:
# <class 'int'>
# 11
# 12

# %%
age = input("Please input your age: ")
print(type(age))
print(age)
print(id(age))
age = int(age)
print(type(age))
print(age)
print(id(age))
# Out:
# <class 'str'>
# 12
# 131600360684880
# <class 'int'>
# 12
# 10446760

# %%
big_num = 12345678901234567890123456787901234567890
print(big_num)
# Out:
# 12345678901234567890123456787901234567890

# %%
bin_num = 0b1010
print(bin_num)
# Out:
# 10

# %%
oct_num = 0o12
print(oct_num)
# Out:
# 10

# %%
oct_num = 0xA
print(oct_num)
# Out:
# 10

# %%
a = 17
b = 12

print("a равно b:", a == b)
print("a не равно b:", a != b)
print("a меньше b:", a < b)
print("a меньше или равно b:", a <= b)
print("a больше b:", a > b)
print("a больше или равно b:", a >= b)
# Out:
# a равно b: False
# a не равно b: True
# a меньше b: False
# a больше или равно b: True

# %%
res = (2 + 2) * 2 ** 2
print(res)
# Out:
# 16

# %% [markdown]
# # float

# %%
num = 10.123
print(num)
print(type(num))
# Out:
# 10.123
# <class 'float'>

# %%
num = 10.0
print(num)
print(type(num))
# Out:
# 10.0
# <class 'float'>

# %%
num = 10
print(num)
print(type(num))
num_1 = float(num)
print(num_1)
print(type(num_1))
# Out:
# 10
# <class 'int'>
# 10.0
# <class 'float'>

# %%
num = "123.456"
print(num)
print(type(num))
num_1 = float(num)
print(num_1)
print(type(num_1))
# Out:
# 123.456
# <class 'str'>
# 123.456
# <class 'float'>

# %%
num = "123.456-"
print(num)
print(type(num))
num_1 = float(num)
print(num_1)
print(type(num_1))
# Out:
# 123.456-
# <class 'str'>
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[56], line 4
#       1 num = "123.456-"
#       2 print(num)
#       3 print(type(num))
# ----> 4 num_1 = float(num)
#       5 print(num_1)
#       6 print(type(num_1))
#
# ValueError: could not convert string to float: '123.456-'

# %%
num = 123.456
print(num)
print(type(num))
num_1 = float(num)
print(num_1)
print(type(num_1))
# Out:
# 123.456
# <class 'float'>
# 123.456
# <class 'float'>

# %%
num_1 = 5.7
num_2 = 3.1

res = num_1 + num_2
print(res)
res = num_1 - num_2
print(res)
res = num_1 * num_2
print(res)
res = num_1 / num_2
print(res)
res = num_1 // num_2
print(res)
res = num_1 % num_2
print(res)
res = num_1 ** num_2
print(res)
# Out:
# 8.8
# 2.6
# 17.67
# 1.8387096774193548
# 1.0
# 2.6
# 220.40023466591268

# %%
range(1, 10, 1)
# Out:
# range(1, 10)

# %%
range(1, 10, 1.0)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[65], line 1
# ----> 1 range(1, 10, 1.0)
#
# TypeError: 'float' object cannot be interpreted as an integer

# %%
print(0.1 + 0.2)
# Out:
# 0.30000000000000004

# %%
print(round((0.1 + 0.2), 2))
# Out:
# 0.3

# %%
x = float("-inf")
y = float("inf")
print(x)
print(type(x))
print(y)
print(type(y))
# Out:
# -inf
# <class 'float'>
# inf
# <class 'float'>

# %%
#

# %% [markdown]
# # Decimal

# %%
from decimal import Decimal

a = Decimal('0.1')
b = Decimal('0.2')
res = a + b
print(res)
print(type(res))
# Out:
# 0.3
# <class 'decimal.Decimal'>

# %%
sum_rub = input("Please input your sum: ")
print(type(sum_rub))
print(sum_rub)
print(id(sum_rub))
sum_rub = float(sum_rub)
print(type(sum_rub))
print(sum_rub)
print(id(sum_rub))
# Out:
# <class 'str'>
# 12.345
#
# 131600360675088
# <class 'float'>
# 12.345
# 131600667274256

# %% [markdown]
# # str

# %%
' " """ '''
# Out:
# ' " """ '

# %%
my_str = 'a'
print(type(my_str))
# Out:
# <class 'str'>

# %%
name = "Bob"
print(name)
# Out:
# Bob

# %%
empty_str = ""
empty_str_1 = ''

# %%
name = "Bob"
last_name = "Ivanov"
full_name = name + last_name
print(full_name)
# Out:
# BobIvanov

# %%
name = "Bob"
print(name)
print(type(name))
print(id(name))
name = name + "qwerty"
print(name)
print(id(name))
# Out:
# Bob
# <class 'str'>
# 131600372078208
# Bobqwerty
# 131600359510320

# %%
name = "Bob"
last_name = "Ivanov"
full_name = f"{name} - {last_name}  ! {32 + 123}"
print(full_name)
# Out:
# Bob - Ivanov  ! 155

# %%
name = "Bob"
last_name = "Ivanov"
full_name = name + " - " + last_name + "  ! " + "123"
print(full_name)
# Out:
# Bob - Ivanov  ! 123

# %%
# Out:
# Bob Ivanov
# Bob Ivanov

# %%
name = "Bob"
print(name * 10)
# Out:
# BobBobBobBobBobBobBobBobBobBob

# %%
name = "Bob"
last_name = "Ivanov"
print(len(name))
print(len(last_name))
print(name[1])
print(last_name[2])
# Out:
# 3
# 6
# o
# a

# %%
text = "heLlO woRld"

# %%
print(text.capitalize())
# Out:
# Hello world

# %%
print(text.lower())
# Out:
# hello world

# %%
print(text.upper())
# Out:
# HELLO WORLD

# %%
print(text.title())
# Out:
# Hello World

# %%
print(text.replace('h', '123'))
# Out:
# 123eLlO woRld

# %%
print(text)
# Out:
# heLlO woRld

# %%
path = "c:\User\Python"
print(path)
# Out:
#   Cell In[104], line 1
#     path = "c:\User\Python"
#            ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %%
path = "c:\\User\\Python"
print(path)
# Out:
# c:\User\Python

# %%
path = r"c:\User\Python"
print(path)
# Out:
# c:\User\Python

# %% [markdown]
# # bool

# %%
is_run = True
is_sun = False
print(is_run)
print(type(is_run))
print(is_sun)
print(type(is_sun))
# Out:
# True
# <class 'bool'>
# False
# <class 'bool'>

# %%
a = 17
b = 12

res = a == b
print(res)
print(type(res))
# Out:
# False
# <class 'bool'>

# %%
p

# %% [markdown]
# # None

# %%
res = None
print(res)
print(type(res))
# Out:
# None
# <class 'NoneType'>

# %%
res = ""

# %% [markdown]
# https://codewars.com
