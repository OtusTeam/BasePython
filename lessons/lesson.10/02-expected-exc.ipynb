# %%
def div_safe(a, b):
    try:
        return a / b
    except ZeroDivisionError:
        print("Division by zero, returning 0")
        return 0

# %%
div_safe(1, 2)
# Out:
# 0.5

# %%
div_safe(10, 2)
# Out:
# 5.0

# %%
div_safe(1, 0)
# Out:
# Division by zero, returning 0
# 0

# %%
def div_safe(a, b):
    print(f"starting div {a=}, {b=}")
    try:
        return a / b
    except ZeroDivisionError:
        print("Division by zero, returning 0")
        return 0

# %%
div_safe(5, 4)
# Out:
# starting div a=5, b=4
# 1.25

# %%
div_safe(5, 0)
# Out:
# starting div a=5, b=0
# Division by zero, returning 0
# 0

# %%
# это очень плохо, так делать не надо

def div_safe(a, b):
    try:
        print(f"starting div {a=}, {b=}")
        print("Hello world")
        print(f"{a}{b}")
        result = a / b
        print("got result", result)
        print(f"{a} / {b} = {result}")
        return result
    except ZeroDivisionError:
        print("Division by zero, returning 0")
        return 0

# %%
div_safe(10, 3)
# Out:
# starting div a=10, b=3
# Hello world
# 103
# got result 3.3333333333333335
# 10 / 3 = 3.3333333333333335
# 3.3333333333333335

# %%
div_safe(10, 0)
# Out:
# starting div a=10, b=0
# Hello world
# 100
# Division by zero, returning 0
# 0

# %%
# это норм вариант

def div(a, b):
    print(f"starting div {a=}, {b=}")
    print("Hello world")
    print(f"{a}{b}")
    result = a / b
    print("got result", result)
    print(f"{a} / {b} = {result}")
    return result


def div_safe(a, b):
    try:
        return div(a, b)
    except ZeroDivisionError:
        print("Division by zero, returning 0")
        return 0

# %%
div_safe(5, 4)
# Out:
# starting div a=5, b=4
# Hello world
# 54
# got result 1.25
# 5 / 4 = 1.25
# 1.25

# %%
div_safe(1, 0)
# Out:
# starting div a=1, b=0
# Hello world
# 10
# Division by zero, returning 0
# 0

# %%
# это норм вариант

def div(a, b):
    print(f"starting div {a=}, {b=}")
    print("Hello world")
    print(f"{a}{b}")
    result = a / b
    print("got result", result)
    print(f"{a} / {b} = {result}")
    return result


def div_safe(a, b):
    try:
        return div(a, b)
    except ZeroDivisionError:
        print("Division by zero, returning 0")

    print("bye world")

# %%
div_safe(1, 1)
# Out:
# starting div a=1, b=1
# Hello world
# 11
# got result 1.0
# 1 / 1 = 1.0
# 1.0

# %%
div_safe(1, 0)
# Out:
# starting div a=1, b=0
# Hello world
# 10
# Division by zero, returning 0
# bye world

# %%
# это продвинутый вариант


def div_safe(a, b):
    print(f"starting div {a=}, {b=}")
    print("Hello world")
    print(f"{a}{b}")
    try:
        result = a / b
    except ZeroDivisionError:
        print("Division by zero, returning None")
    else:
        print("got result", result)
        print(f"{a} / {b} = {result}")
        return result

    print("bye world")

# %%
div_safe(1, 2)
# Out:
# starting div a=1, b=2
# Hello world
# 12
# got result 0.5
# 1 / 2 = 0.5
# 0.5

# %%
div_safe(10, 0)
# Out:
# starting div a=10, b=0
# Hello world
# 100
# Division by zero, returning None
# bye world

# %%
# это продвинутый вариант


def div_safe(a, b):
    print(f"starting div {a=}, {b=}")
    print("Hello world")
    print(f"{a}{b}")
    try:
        result = a / b
    except ZeroDivisionError:
        print("Division by zero, returning None")
        return None

    print("got result", result)
    print(f"{a} / {b} = {result}")
    return result

# %%
div_safe(10, 2)
# Out:
# starting div a=10, b=2
# Hello world
# 102
# got result 5.0
# 10 / 2 = 5.0
# 5.0

# %%
div_safe(1, 0)
# Out:
# starting div a=1, b=0
# Hello world
# 10
# Division by zero, returning None
