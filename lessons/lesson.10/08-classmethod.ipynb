# %%
def validate_username_length(username):
    if len(username) < 3:
        raise ValueError('Username must be at least 3 characters long')
    if len(username) > 20:
        raise ValueError('Username must be at most 20 characters long')
    return username


class User:
    def __init__(self, username):
        self.username = validate_username_length(username)

# %%
john = User('j')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 john = User('j')
#
# Cell In[1], line 11, in User.__init__(self, username)
#      10 def __init__(self, username):
# ---> 11     self.username = validate_username_length(username)
#
# Cell In[1], line 3, in validate_username_length(username)
#       1 def validate_username_length(username):
#       2     if len(username) < 3:
# ----> 3         raise ValueError('Username must be at least 3 characters long')
#       4     if len(username) > 20:
#       5         raise ValueError('Username must be at most 20 characters long')
#
# ValueError: Username must be at least 3 characters long

# %%
john = User('jjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjj')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 john = User('jjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjjj')
#
# Cell In[1], line 11, in User.__init__(self, username)
#      10 def __init__(self, username):
# ---> 11     self.username = validate_username_length(username)
#
# Cell In[1], line 5, in validate_username_length(username)
#       3     raise ValueError('Username must be at least 3 characters long')
#       4 if len(username) > 20:
# ----> 5     raise ValueError('Username must be at most 20 characters long')
#       6 return username
#
# ValueError: Username must be at most 20 characters long

# %%
john = User('john')

# %%
MIN_USERNAME_LENGTH = 3
MAX_USERNAME_LENGTH = 20


def validate_username_length(username):
    if len(username) < MIN_USERNAME_LENGTH:
        raise ValueError(f'Username must be at least {MIN_USERNAME_LENGTH} characters long')
    if len(username) > MAX_USERNAME_LENGTH:
        raise ValueError(f'Username must be at most {MAX_USERNAME_LENGTH} characters long')
    return username


class User:
    def __init__(self, username):
        self.username = validate_username_length(username)

# %%
john = User('j')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 john = User('j')
#
# Cell In[9], line 15, in User.__init__(self, username)
#      14 def __init__(self, username):
# ---> 15     self.username = validate_username_length(username)
#
# Cell In[9], line 7, in validate_username_length(username)
#       5 def validate_username_length(username):
#       6     if len(username) < MIN_USERNAME_LENGTH:
# ----> 7         raise ValueError(f'Username must be at least {MIN_USERNAME_LENGTH} characters long')
#       8     if len(username) > MAX_USERNAME_LENGTH:
#       9         raise ValueError(f'Username must be at most {MAX_USERNAME_LENGTH} characters long')
#
# ValueError: Username must be at least 4 characters long

# %%
john = User('john')

# %%
class User:
    MIN_USERNAME_LENGTH = 3
    MAX_USERNAME_LENGTH = 20

    def __init__(self, username):
        self.username = self.validate_username_length(username)

    @classmethod
    def validate_username_length(cls, username):
        print("cls", cls)
        if len(username) < cls.MIN_USERNAME_LENGTH:
            raise ValueError(f'Username must be at least {cls.MIN_USERNAME_LENGTH} characters long')
        if len(username) > cls.MAX_USERNAME_LENGTH:
            raise ValueError(f'Username must be at most {cls.MAX_USERNAME_LENGTH} characters long')
        return username

# %%
john = User('j')
# Out:
# cls <class '__main__.User'>
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 john = User('j')
#
# Cell In[25], line 6, in User.__init__(self, username)
#       5 def __init__(self, username):
# ----> 6     self.username = self.validate_username_length(username)
#
# Cell In[25], line 12, in User.validate_username_length(cls, username)
#      10 print("cls", cls)
#      11 if len(username) < cls.MIN_USERNAME_LENGTH:
# ---> 12     raise ValueError(f'Username must be at least {cls.MIN_USERNAME_LENGTH} characters long')
#      13 if len(username) > cls.MAX_USERNAME_LENGTH:
#      14     raise ValueError(f'Username must be at most {cls.MAX_USERNAME_LENGTH} characters long')
#
# ValueError: Username must be at least 3 characters long

# %%
john = User('john')
# Out:
# cls <class '__main__.User'>

# %%
class Manager(User):
    MIN_USERNAME_LENGTH = 5

    def __init__(self, username, projects):
        super().__init__(username)
        self.projects = projects

# %%
bob = Manager("bob", ["p1", "p2", "p3"])
# Out:
# cls <class '__main__.Manager'>
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 bob = Manager("bob", ["p1", "p2", "p3"])
#
# Cell In[29], line 5, in Manager.__init__(self, username, projects)
#       4 def __init__(self, username, projects):
# ----> 5     super().__init__(username)
#       6     self.projects = projects
#
# Cell In[25], line 6, in User.__init__(self, username)
#       5 def __init__(self, username):
# ----> 6     self.username = self.validate_username_length(username)
#
# Cell In[25], line 12, in User.validate_username_length(cls, username)
#      10 print("cls", cls)
#      11 if len(username) < cls.MIN_USERNAME_LENGTH:
# ---> 12     raise ValueError(f'Username must be at least {cls.MIN_USERNAME_LENGTH} characters long')
#      13 if len(username) > cls.MAX_USERNAME_LENGTH:
#      14     raise ValueError(f'Username must be at most {cls.MAX_USERNAME_LENGTH} characters long')
#
# ValueError: Username must be at least 5 characters long

# %% [markdown]
# ## Custom init

# %%
class Date:
    def __init__(self, year, month, day):
        self.year = year
        self.month = month
        self.day = day

    def __str__(self):
        return f"{self.year}-{self.month}-{self.day}"

    def __repr__(self):
        return f"{self.__class__.__name__}({self.year}, {self.month}, {self.day})"

# %%
Date(2020, 12, 31)
# Out:
# Date(2020, 12, 31)

# %%
d = Date(2020, 12, 31)
print(d)
# Out:
# 2020-12-31

# %%
from typing import Self


class Date:
    def __init__(self, year, month, day):
        self.year = year
        self.month = month
        self.day = day

    @classmethod
    def from_iso(cls, iso_string: str) -> Self:
        year, month, day = map(int, iso_string.split('-'))
        return cls(year, month, day)

    def __str__(self):
        return f"{self.year}-{self.month}-{self.day}"

    def __repr__(self):
        return f"{self.__class__.__name__}({self.year}, {self.month}, {self.day})"

# %%
d = Date(2020, 12, 31)
print(d)
# Out:
# 2020-12-31

# %%
d2 = Date.from_iso('2025-11-22')
print(d2)
# Out:
# 2025-11-22

# %%
d2
# Out:
# Date(2025, 11, 22)
