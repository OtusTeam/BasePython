# %%
def div(a, b):
    result = a / b
    print(a, "/", b, "=", result)
    return result

# %%
div(10, 4)
# Out:
# 10 / 4 = 2.5
# 2.5

# %%
div(42, 7)
# Out:
# 42 / 7 = 6.0
# 6.0

# %%
div(0, 1)
# Out:
# 0 / 1 = 0.0
# 0.0

# %%
1 / 0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 1 / 0
#
# ZeroDivisionError: division by zero

# %%
div(1, 0)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 div(1, 0)
#
# Cell In[1], line 2, in div(a, b)
#       1 def div(a, b):
# ----> 2     result = a / b
#       3     print(a, "/", b, "=", result)
#       4     return result
#
# ZeroDivisionError: division by zero
