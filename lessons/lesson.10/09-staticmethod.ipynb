# %%
def get_default_permissions():
    return ["read", "write"]


class User:
    def __init__(self, username):
        self.username = username
        self.permissions = get_default_permissions()

# %%
class User:
    def __init__(self, username):
        self.username = username
        self.permissions = self.get_default_permissions()

    @staticmethod
    def get_default_permissions():
        return ["read", "write"]

# %%
user = User("john")

# %%
user.username
# Out:
# 'john'

# %%
user.permissions
# Out:
# ['read', 'write']

# %%
class User:
    def __init__(self, username):
        self.username = username
        self.permissions = self.get_default_permissions()

    @classmethod
    def get_default_permissions(cls):
        return ["read", "write"]

# %%
user = User("john")

# %%
user.username
# Out:
# 'john'

# %%
user.permissions
# Out:
# ['read', 'write']

# %%
User.get_default_permissions()
# Out:
# ['read', 'write']
