# %%
class BaseAPIError(Exception):
    pass


class UnauthorizedError(BaseAPIError):
    pass


class ForbiddenError(BaseAPIError):
    pass


class NotFoundError(BaseAPIError):
    pass


class ConflictError(BaseAPIError):
    pass


class InvalidParamsError(BaseAPIError):
    pass

# %%
class UserNotFoundError(BaseAPIError):
    pass

# %%
def get_user(user_id: int):
    if user_id <= 0:
        raise UserNotFoundError(user_id)
    return {"user_id": user_id, "username": f"user-{user_id}"}

# %%
get_user(1)
# Out:
# {'user_id': 1, 'username': 'user-1'}

# %%
get_user(-1)
# Out:
# ---------------------------------------------------------------------------
# UserNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 get_user(-1)
#
# Cell In[3], line 3, in get_user(user_id)
#       1 def get_user(user_id: int):
#       2     if user_id <= 0:
# ----> 3         raise UserNotFoundError(user_id)
#       4     return {"user_id": user_id, "username": f"user-{user_id}"}
#
# UserNotFoundError: -1

# %%
try:
    get_user(-1)
except UserNotFoundError:
    print("User not found")
# Out:
# User not found

# %%
try:
    get_user(-1)
except BaseAPIError:
    print("cannot fetch user, got API error")
# Out:
# cannot fetch user, got API error

# %%
try:
    get_user(-1)
except UserNotFoundError:
    print("User not found")
except BaseAPIError:
    print("cannot fetch user, got API error")
# Out:
# User not found

# %%
get_user(1)
# Out:
# {'user_id': 1, 'username': 'user-1'}

# %%
from random import random


def get_user(user_id: int):
    if random() < 0.2:
        raise BaseAPIError("something went wrong")
    if user_id == 42:
        raise ForbiddenError("user not available")
    if user_id <= 0:
        raise UserNotFoundError(user_id)
    return {"user_id": user_id, "username": f"user-{user_id}"}

# %%
def user_fetcher(user_id: int):
    try:
        return get_user(user_id)
    except UserNotFoundError:
        print("User not found")
    except ForbiddenError as e:
        print("forbidden:", e)
    except BaseAPIError as e:
        print("cannot fetch user, got API error:", e)

# %%
user_fetcher(1)
# Out:
# cannot fetch user, got API error: something went wrong

# %%
user_fetcher(1)
# Out:
# {'user_id': 1, 'username': 'user-1'}

# %%
user_fetcher(42)
# Out:
# cannot fetch user, got API error: something went wrong

# %%
def get_user(user_id: int):
    if random() < 0.2:
        raise BaseAPIError("something went wrong")
    if user_id == 42:
        raise ForbiddenError("user not available")
    if user_id == 7:
        raise ConflictError("user id already in use")
    if user_id <= 0:
        raise UserNotFoundError(user_id)
    return {"user_id": user_id, "username": f"user-{user_id}"}

# %%
def user_fetcher(user_id: int):
    try:
        return get_user(user_id)
    except UserNotFoundError:
        print("User not found")
    except (ForbiddenError, ConflictError) as e:
        print("cannot access user:", type(e).__name__, e)
    except BaseAPIError as e:
        print("cannot fetch user, got API error:", e)

# %%
user_fetcher(1)
# Out:
# {'user_id': 1, 'username': 'user-1'}

# %%
user_fetcher(1)
# Out:
# cannot fetch user, got API error: something went wrong

# %%
user_fetcher(-1)
# Out:
# User not found

# %%
user_fetcher(-10)
# Out:
# cannot fetch user, got API error: something went wrong

# %%
user_fetcher(-10)
# Out:
# User not found

# %%
user_fetcher(7)
# Out:
# cannot access user: ConflictError user id already in use

# %%
user_fetcher(42)
# Out:
# cannot fetch user, got API error: something went wrong

# %%
user_fetcher(42)
# Out:
# cannot access user: ForbiddenError user not available

# %%
class UserNotFoundError(BaseAPIError):
    def __init__(self, user_id: int):
        super().__init__(f"User {user_id} not found")
        self.user_id = user_id

# %%
def get_user(user_id: int):
    if random() < 0.2:
        raise BaseAPIError("something went wrong")
    if user_id == 42:
        raise ForbiddenError("user not available")
    if user_id == 7:
        raise ConflictError("user id already in use")
    if user_id <= 0:
        raise UserNotFoundError(user_id)
    return {"user_id": user_id, "username": f"user-{user_id}"}

# %%
def user_fetcher(user_id: int):
    try:
        return get_user(user_id)
    except UserNotFoundError as e:
        print(e)
        # print("no user with id =", user_id)
        print("no user with id =", e.user_id)
    except (ForbiddenError, ConflictError) as e:
        print("cannot access user:", type(e).__name__, e)
    except BaseAPIError as e:
        print("cannot fetch user, got API error:", e)

# %%
user_fetcher(-1)
# Out:
# cannot fetch user, got API error: something went wrong

# %%
user_fetcher(-1)
# Out:
# cannot fetch user, got API error: something went wrong

# %%
user_fetcher(-1)
# Out:
# User -1 not found
# no user with id = -1
