# %%
# никогда не делаем except Exception
def div_safe(a, b):
    try:
        return a / b
    except Exception as e:
        print("got an exception:", type(e), e)

# %%
div_safe(1, 2)
# Out:
# 0.5

# %%
div_safe(1, 0)
# Out:
# got an exception: <class 'ZeroDivisionError'> division by zero

# %%
div_safe("1", 1)
# Out:
# got an exception: <class 'TypeError'> unsupported operand type(s) for /: 'str' and 'int'
